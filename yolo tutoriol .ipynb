# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.64  Python-3.12.8 torch-2.5.1+cpu CPU (Intel Core(TM) i5-4200U 1.60GHz)
# Setup complete  (4 CPUs, 5.9 GB RAM, 91.8/237.8 GB disk)

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolo11n.pt')

# %%
source=r"C:\Users\ACER\youssef\yolo\manel.jpeg

# %%
results = model.predict(source=source, save=True)
# Out:
# image 1/1 C:\Users\ACER\Downloads\manel.jpeg: 480x640 2 persons, 305.7ms
# Speed: 5.4ms preprocess, 305.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict2

# %%
ls
# Out:
#  Le volume dans le lecteur C n’a pas de nom.
#  Le numéro de série du volume est 4A2A-0006
#
#  Répertoire de C:\Users\ACER\youssef
#
# 21/01/2025  08:07 AM    <DIR>          .
# 21/01/2025  08:07 AM    <DIR>          ..
# 20/01/2025  11:29 AM    <DIR>          .ipynb_checkpoints
# 01/11/2024  02:32 PM    <DIR>          Braest Cancer Classification with NN
# 03/10/2024  06:37 PM    <DIR>          car price prediction
# 11/10/2024  08:08 AM    <DIR>          churn project
# 05/12/2024  11:34 AM    <DIR>          fraudulent transactions prediction for a financial company
# 22/12/2024  09:31 PM    <DIR>          Gemma project
# 23/10/2024  04:38 PM    <DIR>          house price prediction
# 06/11/2024  02:45 PM    <DIR>          image classification
# 15/09/2024  02:39 PM           913 314 main.ipynb
# 09/12/2024  03:54 PM    <DIR>          mcq
# 27/10/2024  05:18 PM    <DIR>          neural network project
# 04/12/2024  02:08 PM    <DIR>          predict employee retention
# ...

# %%
results = model.predict(source='C:/Users/ACER/Downloads/manel.jpeg', save=True, save_dir='C:/Users/ACER/youssef/yolo')
# Out:
# image 1/1 C:\Users\ACER\Downloads\manel.jpeg: 480x640 2 persons, 348.4ms
# Speed: 5.8ms preprocess, 348.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict2

# %%
# Run inference on an image with YOLO11n

# !yolo predict model=yolo11n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# Ultralytics 8.3.64 ðŸš€ Python-3.12.8 torch-2.5.1+cpu CPU (Intel Core(TM) i5-4200U 1.60GHz)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# ...
# image 1/1 C:\Users\ACER\youssef\zidane.jpg: 384x640 2 persons, 1 tie, 224.1ms
# Speed: 10.1ms preprocess, 224.1ms inference, 30.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/predict
#   0%|          | 0.00/49.2k [00:00<?, ?B/s]
# 100%|##########| 49.2k/49.2k [00:00<00:00, 1.24MB/s]

# %%
import os
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: C:\Users\ACER\youssef

# %%
import os

file_path = r"C:\Users\ACER\youssef\yolo\manel.jpeg"  # Replace with your file path
if os.path.exists(file_path):
    print(f"File found: {file_path}")
    results = model.predict(source=file_path, save=True)
else:
    print(f"File not found: {file_path}")
# Out:
# File found: C:\Users\ACER\youssef\yolo\manel.jpeg
#
# image 1/1 C:\Users\ACER\youssef\yolo\manel.jpeg: 480x640 2 persons, 527.4ms
# Speed: 31.2ms preprocess, 527.4ms inference, 35.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict2

# %%
model = YOLO("yolo11l.pt")
# Out:
# ...
# 100%|██████████| 49.0M/49.0M [00:41<00:00, 1.24MB/s]

# %%
# check the class names available
model.names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
# ...

# %%
file_path1 = r"C:\Users\ACER\youssef\yolo\video.mp4"

# %%
result = model.predict(file_path1,
              conf=0.5,
              save=True,
              save_txt=True   
              )
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/3757) C:\Users\ACER\youssef\yolo\video.mp4: 384x640 14 cars, 1469.9ms
# video 1/1 (frame 2/3757) C:\Users\ACER\youssef\yolo\video.mp4: 384x640 14 cars, 1283.8ms
# video 1/1 (frame 3/3757) C:\Users\ACER\youssef\yolo\video.mp4: 384x640 14 cars, 1113.7ms
# video 1/1 (frame 4/3757) C:\Users\ACER\youssef\yolo\video.mp4: 384x640 14 cars, 1176.2ms
# ...

# %%
for r in result:
  continue

# %%
# !ffmpeg -y -i runs/detect/predict3/video.avi video.mp4
# Out:
# 'ffmpeg' n’est pas reconnu en tant que commande interne
# ou externe, un programme exécutable ou un fichier de commandes.
